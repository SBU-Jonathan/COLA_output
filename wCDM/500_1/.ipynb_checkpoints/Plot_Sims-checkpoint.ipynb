# %%
import os
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import euclidemu2 as ee2

# %%
# GENERAL PLOT OPTIONS
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'
matplotlib.rcParams['xtick.bottom'] = True
matplotlib.rcParams['xtick.top'] = False
matplotlib.rcParams['ytick.right'] = False
matplotlib.rcParams['axes.edgecolor'] = 'black'
matplotlib.rcParams['axes.linewidth'] = '1.0'
matplotlib.rcParams['axes.labelsize'] = 'medium'
matplotlib.rcParams['axes.grid'] = True
matplotlib.rcParams['grid.linewidth'] = '0.0'
matplotlib.rcParams['grid.alpha'] = '0.18'
matplotlib.rcParams['grid.color'] = 'lightgray'
matplotlib.rcParams['legend.labelspacing'] = 0.77
matplotlib.rcParams['savefig.bbox'] = 'tight'
matplotlib.rcParams['savefig.format'] = 'pdf'
matplotlib.rcParams['axes.labelsize'] = 18
matplotlib.rcParams['xtick.labelsize'] = 18
matplotlib.rcParams['ytick.labelsize'] = 18
matplotlib.rcParams['axes.titlesize'] = 18

# %%
def get_pks_from_file(run_name, redshift=0, test=False, ph_rev=False, out_ks=True):
    """
    Description: returns the linear and non-linear power spectra from COLA simulations at a given redshift. Optionally, return the COLA scales k.
    """
    ks, pk_nl, pk_lin = np.loadtxt(f"./a/output/{run_name}/pofk_{run_name}_total_z{redshift:.3f}.txt", unpack=True) if test else np.loadtxt(f"./a/output/{run_name}/pofk_run_{run_name}_total_z{redshift:.3f}.txt", unpack=True)    
    if ph_rev:
        pk_nl_2, pk_lin = np.loadtxt(f"./b/output/{run_name}ph_rev/pofk_{run_name}ph_rev_total_z{redshift:.3f}.txt", unpack=True, usecols=(1,2)) if test else np.loadtxt(f"./b/output/{run_name}ph_rev/pofk_run_{run_name}ph_rev_total_z{redshift:.3f}.txt", unpack=True, usecols=(1,2))
        pk_nl = (pk_nl + pk_nl_2)/2
    if out_ks:
        return ks, pk_nl, pk_lin
    return pk_nl, pk_lin

# %%
ref_params = {
    "h": 0.67,
    "Omm": 0.319,
    "Omb": 0.049,
    "As": 2.1e-9,
    "ns": 0.96,
    "w": -1,
    "wa": 0,
    "mnu": 0.058
}
ks, pk_nl_ref, pk_lin_ref = get_pks_from_file("test_2", redshift=0, test=True, ph_rev=True, out_ks=True)
ks, ref_boost_ee2 = ee2.get_boost(ref_params, [0], ks)
# Out:
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.

# %%
lhs = np.loadtxt("lhs.txt")

# %%
# Plot test boosts against EE2
ks, pk_nl_ref, pk_lin_ref = get_pks_from_file("test_2", redshift=0, test=True, ph_rev=True, out_ks=True)
ws = [-1.3, -0.7]
plt.figure(figsize=(10,10))
for i, w in enumerate(ws):
    params = {
        "h": 0.67,
        "Omm": 0.319,
        "Omb": 0.049,
        "As": 2.1e-9,
        "ns": 0.96,
        "w": w,
        "wa": 0,
        "mnu": 0.058
    }
    ks, boost_ee2 = ee2.get_boost(params, [0], ks)
    pk_nl, pk_lin = get_pks_from_file(f"test_{i}", test=True, ph_rev=True, out_ks=False)
    r_nl = pk_nl/pk_nl_ref
    r_lin = pk_lin/pk_lin_ref
    boost_cola = ref_boost_ee2[0] * r_nl/r_lin
    plt.semilogx(ks, boost_cola/boost_ee2[0] - 1)
plt.axhline(0, color='gray', ls='--')
plt.xlabel("$k$ (h/Mpc)")
plt.ylabel("Boost relative error")
plt.title("Test wCDM simulations")
# Out:
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Text(0.5, 1.0, 'Test wCDM simulations')

# %%
# Plot LHS boosts against EE2
plotted = 0
redshift = 0
ks, pk_nl_ref, pk_lin_ref = get_pks_from_file("test_2", redshift=redshift, test=True, ph_rev=True, out_ks=True)
issues = []
for i, sample in enumerate(lhs):
    try:
        pk_nl, pk_lin = get_pks_from_file(f"{i}", redshift=redshift, ph_rev=True, out_ks=False)
    except Exception as err:
        print(f"WARNING: Did not read cosmology {i}: {err}")
        continue
    params = {
        "h": sample[4],
        "Omm": sample[0],
        "Omb": sample[1],
        "As": sample[3],
        "ns": sample[2],
        "w": sample[5],
        "wa": 0,
        "mnu": 0.058
    }
    try:
        ks, boost_ee2 = ee2.get_boost(params,[redshift], ks)
    except Exception as err:
        print(f"Cosmology {i} is outside the EE2 box.")
        continue
    r_nl = pk_nl/pk_nl_ref
    r_lin = pk_lin/pk_lin_ref
    boost_cola = ref_boost_ee2[redshift] * r_nl/r_lin
    errors = boost_cola/boost_ee2[0] - 1
    if abs(errors[1]) > 0.005:
        print(f"WARNING: Cosmology {i} has first bin error above 1%.")
        issues.append(i)
    plt.semilogx(ks[1:], errors[1:])
    plotted = plotted+1

plt.xlim([0.02,2])
plt.ylim([-0.059,0.059])

plt.xlabel("k")
plt.ylabel(r"$B_\mathrm{COLA}/B_\mathrm{EE2} - 1$")
plt.title(f"COLA Simulation Boosts vs EE2, z = {redshift:.2f}")
plt.savefig(f"results_z={redshift:.1f}.pdf", bbox_inches='tight')
print(f"Plotted {plotted} cosmologies")
# Out:
# Cosmology 0 is outside the EE2 box.
# Cosmology 1 is outside the EE2 box.
# Cosmology 2 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 4 is outside the EE2 box.
# Cosmology 5 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 8 is outside the EE2 box.
# Cosmology 9 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 12 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 16 is outside the EE2 box.
# Cosmology 17 is outside the EE2 box.
# Cosmology 18 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 26 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 32 is outside the EE2 box.
# Cosmology 33 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 36 is outside the EE2 box.
# Cosmology 37 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 43 is outside the EE2 box.
# Cosmology 44 is outside the EE2 box.
# Cosmology 45 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 55 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 58 is outside the EE2 box.
# Cosmology 59 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 61 is outside the EE2 box.
# Cosmology 62 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 65 is outside the EE2 box.
# Cosmology 66 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 71 is outside the EE2 box.
# Cosmology 72 is outside the EE2 box.
# Cosmology 73 is outside the EE2 box.
# Cosmology 74 is outside the EE2 box.
# Cosmology 75 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 78 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 79 has first bin error above 1%.
# Cosmology 80 is outside the EE2 box.
# Cosmology 81 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 82 has first bin error above 1%.
# Cosmology 83 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 86 is outside the EE2 box.
# Cosmology 87 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 89 is outside the EE2 box.
# Cosmology 90 is outside the EE2 box.
# Cosmology 91 is outside the EE2 box.
# Cosmology 92 is outside the EE2 box.
# Cosmology 93 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 95 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 97 is outside the EE2 box.
# Cosmology 98 is outside the EE2 box.
# Cosmology 99 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 101 is outside the EE2 box.
# Cosmology 102 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 107 is outside the EE2 box.
# Cosmology 108 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 111 is outside the EE2 box.
# Cosmology 112 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 116 is outside the EE2 box.
# Cosmology 117 is outside the EE2 box.
# Cosmology 118 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 120 is outside the EE2 box.
# Cosmology 121 is outside the EE2 box.
# Cosmology 122 is outside the EE2 box.
# Cosmology 123 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 125 is outside the EE2 box.
# Cosmology 126 is outside the EE2 box.
# Cosmology 127 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 129 is outside the EE2 box.
# Cosmology 130 is outside the EE2 box.
# Cosmology 131 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 134 has first bin error above 1%.
# Cosmology 135 is outside the EE2 box.
# Cosmology 136 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 142 is outside the EE2 box.
# Cosmology 143 is outside the EE2 box.
# Cosmology 144 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 153 is outside the EE2 box.
# Cosmology 154 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 156 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 158 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 167 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 170 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 172 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 174 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 176 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 178 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 180 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 183 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 186 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 190 is outside the EE2 box.
# Cosmology 191 is outside the EE2 box.
# Cosmology 192 is outside the EE2 box.
# Cosmology 193 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 197 is outside the EE2 box.
# Cosmology 198 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 202 is outside the EE2 box.
# Cosmology 203 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 209 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 211 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 220 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 223 is outside the EE2 box.
# Cosmology 224 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 229 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 234 is outside the EE2 box.
# Cosmology 235 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 239 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 242 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 247 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 250 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 254 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 256 is outside the EE2 box.
# Cosmology 257 is outside the EE2 box.
# Cosmology 258 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 264 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 268 is outside the EE2 box.
# Cosmology 269 is outside the EE2 box.
# Cosmology 270 is outside the EE2 box.
# Cosmology 271 is outside the EE2 box.
# Cosmology 272 is outside the EE2 box.
# Cosmology 273 is outside the EE2 box.
# Cosmology 274 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 280 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 283 is outside the EE2 box.
# Cosmology 284 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 286 is outside the EE2 box.
# Cosmology 287 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 290 is outside the EE2 box.
# Cosmology 291 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 294 is outside the EE2 box.
# Cosmology 295 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 297 is outside the EE2 box.
# Cosmology 298 is outside the EE2 box.
# Cosmology 299 is outside the EE2 box.
# Cosmology 300 is outside the EE2 box.
# Cosmology 301 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 303 is outside the EE2 box.
# Cosmology 304 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 305 has first bin error above 1%.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 307 is outside the EE2 box.
# Cosmology 308 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 311 is outside the EE2 box.
# Cosmology 312 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 316 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 318 is outside the EE2 box.
# Cosmology 319 is outside the EE2 box.
# Cosmology 320 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 324 has first bin error above 1%.
# Cosmology 325 is outside the EE2 box.
# Cosmology 326 is outside the EE2 box.
# Cosmology 327 is outside the EE2 box.
# Cosmology 328 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 332 is outside the EE2 box.
# Cosmology 333 is outside the EE2 box.
# Cosmology 334 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 336 is outside the EE2 box.
# Cosmology 337 is outside the EE2 box.
# Cosmology 338 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 340 is outside the EE2 box.
# Cosmology 341 is outside the EE2 box.
# Cosmology 342 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 345 is outside the EE2 box.
# Cosmology 346 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 354 is outside the EE2 box.
# Cosmology 355 is outside the EE2 box.
# Cosmology 356 is outside the EE2 box.
# Cosmology 357 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 360 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 365 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# ...
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 376 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 378 is outside the EE2 box.
# Cosmology 379 is outside the EE2 box.
# Cosmology 380 is outside the EE2 box.
# Cosmology 381 is outside the EE2 box.
# Cosmology 382 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 388 is outside the EE2 box.
# Cosmology 389 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 391 is outside the EE2 box.
# Cosmology 392 is outside the EE2 box.
# Cosmology 393 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 395 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 397 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 400 is outside the EE2 box.
# Cosmology 401 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 404 is outside the EE2 box.
# Cosmology 405 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 407 is outside the EE2 box.
# Cosmology 408 is outside the EE2 box.
# Cosmology 409 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 411 is outside the EE2 box.
# Cosmology 412 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 414 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# WARNING: Cosmology 418 has first bin error above 1%.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 422 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 426 is outside the EE2 box.
# Cosmology 427 is outside the EE2 box.
# Cosmology 428 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 431 is outside the EE2 box.
# Cosmology 432 is outside the EE2 box.
# Cosmology 433 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 437 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 442 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 445 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 447 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 450 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 456 is outside the EE2 box.
# Cosmology 457 is outside the EE2 box.
# Cosmology 458 is outside the EE2 box.
# Cosmology 459 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 463 is outside the EE2 box.
# Cosmology 464 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 468 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 470 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 475 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 477 is outside the EE2 box.
# Cosmology 478 is outside the EE2 box.
# Cosmology 479 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 482 is outside the EE2 box.
# Cosmology 483 is outside the EE2 box.
# Cosmology 484 is outside the EE2 box.
# Cosmology 485 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 490 is outside the EE2 box.
# Cosmology 491 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 493 is outside the EE2 box.
# Cosmology 494 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Cosmology 496 is outside the EE2 box.
# Cosmology 497 is outside the EE2 box.
# Cosmology 498 is outside the EE2 box.
# Warning:
# EuclidEmulator2 emulates the non-linear correction in
# the interval [8.73e-3 h/Mpc, 9.41h/Mpc]. You are
# requesting k modes below k_min = 8.73e-3 h/Mpc.
# Lower k modes constantly extrapolated.
# Plotted 279 cosmologies

# %%
issues
# Out:
# [79, 82, 134, 305, 324, 418]

# %%
print("Cosmological parameters of 'bad' cosmologies (order: Omega_m, Omega_b, ns, As, h, w)")
for code in issues:
    print(f'{code}: {lhs[code]}')
# Out:
# Cosmological parameters of 'bad' cosmologies (order: Omega_m, Omega_b, ns, As, h, w)
# 79: [ 2.50214768e-01  5.81438654e-02  9.93576625e-01  2.10225233e-09
#   6.81399846e-01 -1.27810417e+00]
# 82: [ 2.62284840e-01  4.31441843e-02  9.39441155e-01  2.45311250e-09
#   6.84271868e-01 -1.29005473e+00]
# 134: [ 2.52705179e-01  5.48993671e-02  9.86880291e-01  2.19356617e-09
#   6.57004791e-01 -1.27004615e+00]
# 305: [ 2.55633239e-01  5.89881671e-02  9.41954825e-01  2.34176469e-09
#   6.97747984e-01 -1.29616706e+00]
# 324: [ 2.62718128e-01  4.54527580e-02  9.40319643e-01  1.98918000e-09
#   7.17836087e-01 -1.29529068e+00]
# 418: [ 2.58390354e-01  4.96301877e-02  9.45776744e-01  1.81661324e-09
#   6.11586357e-01 -1.28518217e+00]
